# %%
import pandas as pd
x='/home/kavya/Documents/Population..xlsx'
df=pd.read_excel(x)
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
print(df)
# Out:
#          Name  Age  Gender Branch     ID No   CGPA
# 0      Kalyan   18    Male    CSE  RO200220  10.00
# 1         Ram   19    Male    CSE  RO200221   9.00
# 2         Raj   18    Male    CSE  RO200222   8.50
# 3        Ravi   18    Male    CSE  RO200223   9.50
# 4        Suji   19  Female    CSE  RO200224   9.40
# 5        Suma   20  Female    CSE  RO200225   9.10
# 6    Srivalli   21  Female    CSE  RO200226  10.00
# 7       Shiva   23    Male    CSE  RO200227   9.80
# 8     Gayatri   24  Female    CSE  RO200228   9.90
# 9       Ragav   19    Male    CSE  RO200229  10.00
# 10     Rakesh   18    Male    CSE  RO200230  10.00
# 11     Mahesh   19    Male    CSE  RO200231   9.40
# 12       Mahi   20    Male    ECE  RO200232   8.30
# 13    Radhika   21  Female    ECE  RO200233   8.40
# 14    Mahidar   22    Male    ECE  RO200234   8.60
# 15      Mahan   17    Male    ECE  RO200235  10.00
# 16    Mounika   18  Female    ECE  RO200236   9.80
# 17      Latha   19  Female    ECE  RO200237   9.70
# 18       Raju   20    Male    ECE  RO200238   9.40
# 19     Raveen   21    Male   MECH  RO200239   9.30
# 20     Mubina   22  Female   MECH  RO200240  10.00
# 21    Praveen   23    Male   MECH  RO200241   9.00
# 22       Anin   24    Male   MECH  RO200242   9.10
# 23     Suresh   20    Male   MECH  RO200243   9.30
# 24       Suri   21    Male   MECH  RO200244   9.30
# 25  Ravikanth   22    Male   MECH  RO200245  10.00
# 26     Chandu   23    Male   MECH  RO200246   8.70
# 27  Chandhini   19  Female   MECH  RO200247   7.40
# 28    Sahithi   18  Female   MECH  RO200248   9.00
# 29       Devi   18  Female    CSE  RO200249   9.90
# 30     Devika   18  Female    ECE  RO200250   9.30
# 31   Shivanya   20  Female  CIVIL  RO200251   9.21
# 32      David   20    Male  CIVIL  RO200252   8.50
# 33      Vijay   21    Male   MECH  RO200253   7.80
# 34       Ajay   22    Male    ECE  RO200254   8.80
# 35     Antony   23    Male    CSE  RO200255   9.80
# 36     Prabhu   24    Male    CSE  RO200256   9.90
# 37     Kusuma   25  Female    CSE  RO200257  10.00
# 38     Kumari   26  Female  CIVIL  RO200258  10.00
# 39  Kanyanika   20  Female  CIVIL  RO200259   9.50
# 40  Bhuvanika   20  Female   MECH  RO200260   9.80
# 41      Vishu   19  Female    EEE  RO200261   7.40
# 42     Mehren   19  Female    EEE  RO200262   8.40
# 43     Muskan   28  Female    CSE  RO200263   8.90
# 44      Malli   22    Male    EEE  RO200264   8.80
# 45   Srikanth   21    Male    EEE  RO200265  10.00
# 46    Sridhar   19    Male    CSE  RO200266   9.40
# 47     Venkat   18    Male    ECE  RO200267   9.30
# 48  Venkatesh   18    Male    ECE  RO200268   9.90
# 49  Veerendra   20    Male    ECE  RO200269  10.00

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x='/home/kavya/Documents/Population..xlsx'
df=pd.read_excel(x)
particular_column=df[['Age','Gender']]
print(particular_column.head(10))
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
age_data=df['Age']
gender_data=df['Gender']
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Distribution of Age and Gender using Data Visulization like barcharts')
plt.bar(gender_data,age_data,width=0.7,color='yellow')
plt.show()
# Out:
#    Age  Gender
# 0   18    Male
# 1   19    Male
# 2   18    Male
# 3   18    Male
# 4   19  Female
# 5   20  Female
# 6   21  Female
# 7   23    Male
# 8   24  Female
# 9   19    Male

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x='/home/kavya/Documents/Population..xlsx'
df=pd.read_excel(x)
particular_column=df[['Age','Gender']]
print(particular_column.head(10))
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
print(df)
age_data=df['Age']
gender_data=df['Gender']
plt.xlabel('Age')

plt.title('Distribution of Age and Gender using Data Visulization like hist')
plt.hist(age_data,bins=2,color='pink')
plt.show()
# Out:
#    Age  Gender
# 0   18    Male
# 1   19    Male
# 2   18    Male
# 3   18    Male
# 4   19  Female
# 5   20  Female
# 6   21  Female
# 7   23    Male
# 8   24  Female
# 9   19    Male

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x='/home/kavya/Documents/Population..xlsx'
df=pd.read_excel(x)
particular_column=df[['Age','Gender']]
print(particular_column.head(10))
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
age_data=df['Age']
gender_data=df['Gender']
plt.xlabel('Age')

plt.title('Distribution of Age and Gender using Data Visulization like hist')
plt.hist(gender_data,bins=2,color='green')
plt.show()
# Out:
#    Age  Gender
# 0   18    Male
# 1   19    Male
# 2   18    Male
# 3   18    Male
# 4   19  Female
# 5   20  Female
# 6   21  Female
# 7   23    Male
# 8   24  Female
# 9   19    Male
